# %%
# !pip install -U google-genai

# %%
from google import genai

# %%
client = genai.Client(api_key="AQ.Ab8RN6LEzIFSZR4oK1YIuDB9o63ZtDQo_jdwtljSJKWGTwF58Q")

# %%
MODEL = "models/gemini-3.5-flash"

# %%
def travel_agent(user_input):

    prompt = f"""
You are a professional travel agent for Pakistan tourism.

Provide a well-structured travel plan with clear headings:

1. Destination Overview
2. Budget Travel Options (Bus, Train, Flight with approx cost in PKR)
3. Places to Visit (specific locations)
4. Food Suggestions (local dishes)
5. Money-Saving Tips

Make response detailed but easy for students.

User request: {user_input}

Travel Plan:
"""

    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text

# %%
print("Gemini Travel Agent Started (type 'exit' to stop)\n")

while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye")
        break

    try:
        reply = travel_agent(user)
        print("\nAgent:\n", reply, "\n")

    except Exception as e:
        print("Error:", e)
# Out:
# Gemini Travel Agent Started (type 'exit' to stop)
#
# You: Plan a 3-day trip to Hunza from Karachi
# WARNING:google_genai.models:Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# Agent:
#  ### 1. Destination Overview
#
# Welcome to **Hunza Valley**, often referred to as the "Heaven on Earth." Located in the northernmost part of Gilgit-Baltistan, Hunza is surrounded by towering peaks like Rakaposhi, Ladyfinger, and Mount Ultar. For students, Hunza is the ultimate getaway. It offers a perfect blend of rich culture, unmatched hospitality, thrilling adventure, and breathtaking landscapes—all within a highly safe and peaceful environment.
#
# ...

# %%
def vacuum_agent(user_input):

    prompt = f"""
You are an intelligent automated vacuum cleaner agent.

Analyze the user's request and provide a clear response about
vacuum cleaning tasks.

The agent should consider:
- Current location
- Dirt or dust level
- Obstacles
- Cleaning status
- Battery level
- Rooms that need cleaning

Provide a well-structured response with clear headings:

1. Current Situation
2. Cleaning Plan
3. Actions to Perform
4. Battery Status
5. Cleaning Summary

Make the response detailed but easy for students.

User request: {user_input}

Vacuum Agent Response:
"""

    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text

# %%
print("Automated Vacuum Cleaner Agent Started (type 'exit' to stop)\n")

while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye")
        break

    try:
        reply = vacuum_agent(user)
        print("\nAgent:\n", reply, "\n")

    except Exception as e:
        print("Error:", e)
# Out:
# Automated Vacuum Cleaner Agent Started (type 'exit' to stop)
#
# You: Clean the living room and bedroom. The living room has a lot of dust and the battery is 70%.
#
# Agent:
#  ### 1. Current Situation
# * **Current Location:** Charging Dock (Hallway)
# * **Status:** Standby (Ready to begin task)
# * **Target Rooms:** Living Room and Bedroom
# * **Detected Dust/Dirt Levels:**
#   * **Living Room:** High (Heavy dust accumulation detected)
#   * **Bedroom:** Low to Moderate (Standard daily dust)
# * **Identified Obstacles (from previous map memory):**
#   * **Living Room:** Coffee table, sofa legs, and a shaggy area rug.
#   * **Bedroom:** Bedposts, nightstands, and loose slippers on the floor.
#
# ---
#
# ### 2. Cleaning Plan
# To clean efficiently before the battery runs out, the agent will follow a prioritized route:
# ...
